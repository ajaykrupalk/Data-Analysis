# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <b>Importing COVID-19 DATASET</b>

# %%
corona_dataset_csv=pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv')
print(corona_dataset_csv.shape)#gives no. of columns and rows
# Out:
# (266, 217)

# %%
print(corona_dataset_csv.head(10))#prints first 5 rows
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  8/12/20  \
# 0        0        0        0        0        0        0  ...    37345
# ...

# %% [markdown]
# <b>Deleting the useless columns</b>

# %%
df=corona_dataset_csv.drop(["Lat","Long"],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  8/12/20  \
# 0        0        0        0        0        0        0  ...    37345
# ...

# %%
corona_dataset_aggregated=corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  8/12/20  \
# Country/Region                                           ...
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (188, 213)

# %% [markdown]
# <b>Comparison of countries</b>

# %%
corona_dataset_aggregated.loc["India"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Australia"].plot()
plt.legend()#adds legend to the graph

# %% [markdown]
# <b> Calculating the good measure </b>

# %% [markdown]
# Finding the growth rate for the first 3 days

# %%
corona_dataset_aggregated.loc["India"][:3].plot()

# %% [markdown]
# <b> Calculating and plotting the first derivative of the curve </b>

# %%
corona_dataset_aggregated.loc["India"].diff().plot()

# %% [markdown]
# <b> Finding the maximum infection rate </b>

# %% [markdown]
# The everyday increase in the number of cases

# %%
corona_dataset_aggregated.loc["India"].diff().max()
# Out:
# 69876.0

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 16269.0

# %% [markdown]
# <b> Find maximum infection rate for all of the countries </b>

# %% [markdown]
# Create a new column to store the maximum infection rates

# %%
countries=list(corona_dataset_aggregated.index)
max_infection_rates=[]
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated['max_infection_rate']=max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  8/13/20  8/14/20  8/15/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    37424    37431    37551
# Albania               0        0        0  ...     6971     7117     7260
# Algeria               0        0        0  ...    37187    37664    38133
# Andorra               0        0        0  ...      981      989      989
# ...

# %% [markdown]
# <b> Creating a database with only needed columns </b>

# %%
corona_data=pd.DataFrame(corona_dataset_aggregated['max_infection_rate'])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  915.0
# Albania                      158.0
# Algeria                      675.0
# Andorra                       79.0
# Angola                       100.0

# %% [markdown]
# <b> Importing another dataset </b>

# %%
recovered_cases=pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_recovered_global.csv&filename=time_series_covid19_recovered_global.csv')

# %%
recovered_cases.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  8/12/20  8/13/20  8/14/20  \
# 0        0        0        0        0  ...    26694    26714    26714
# 1        0        0        0        0  ...     3552     3616     3695
# 2        0        0        0        0  ...    25627    26004    26308
# 3        0        0        0        0  ...      855      858      863
# 4        0        0        0        0  ...      577      577      584
#
#    8/15/20  8/16/20  8/17/20  8/18/20  8/19/20  8/20/20  8/21/20
# ...

# %% [markdown]
# <b> Drop the useless columns </b>

# %%
recovered_cases.drop(["Lat","Long"],axis=1,inplace=True)
recovered_cases.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  8/12/20  8/13/20  8/14/20  8/15/20  \
# 0        0        0        0  ...    26694    26714    26714    27166
# 1        0        0        0  ...     3552     3616     3695     3746
# 2        0        0        0  ...    25627    26004    26308    26644
# 3        0        0        0  ...      855      858      863      863
# 4        0        0        0  ...      577      577      584      628
#
#    8/16/20  8/17/20  8/18/20  8/19/20  8/20/20  8/21/20
# ...

# %% [markdown]
# <b> Changing the indices of the databases </b>

# %%
recovered_cases_aggregated=recovered_cases.groupby("Country/Region").sum()

# %%
recovered_cases_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  8/12/20  8/13/20  8/14/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    26694    26714    26714
# Albania               0        0        0  ...     3552     3616     3695
# Algeria               0        0        0  ...    25627    26004    26308
# Andorra               0        0        0  ...      855      858      863
# ...

# %%
corona_data.shape
# Out:
# (188, 1)

# %%
recovered_cases_aggregated.shape
# Out:
# (188, 213)

# %% [markdown]
# <b> Find maximum recovery rate for all countries </b>

# %%
all_countries=list(recovered_cases_aggregated.index)
max_recovery_rates=[]
for c in countries:
    max_recovery_rates.append(recovered_cases_aggregated.loc[c].diff().max())
recovered_cases_aggregated['max_recovery_rate']=max_recovery_rates

# %%
recovered_cases_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  8/13/20  8/14/20  8/15/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    26714    26714    27166
# Albania               0        0        0  ...     3616     3695     3746
# Algeria               0        0        0  ...    26004    26308    26644
# Andorra               0        0        0  ...      858      863      863
# ...

# %% [markdown]
# <b> Creating a database with only needed columns </b>

# %%
recovered_data=pd.DataFrame(recovered_cases_aggregated['max_recovery_rate'])
recovered_data.head()
# Out:
#                 max_recovery_rate
# Country/Region
# Afghanistan                1930.0
# Albania                     110.0
# Algeria                     749.0
# Andorra                      57.0
# Angola                       94.0

# %% [markdown]
# <b> Joining two databases </b>

# %%
data=corona_data.join(recovered_data)
data.head()
# Out:
#                 max_infection_rate  max_recovery_rate
# Country/Region
# Afghanistan                  915.0             1930.0
# Albania                      158.0              110.0
# Algeria                      675.0              749.0
# Andorra                       79.0               57.0
# Angola                       100.0               94.0

# %% [markdown]
# <b> Correlation Matrix </b>

# %%
data.corr()
# Out:
#                     max_infection_rate  max_recovery_rate
# max_infection_rate            1.000000           0.855526
# max_recovery_rate             0.855526           1.000000

# %% [markdown]
# <b> Visualisation of the results </b>

# %%
data.head()
# Out:
#                 max_infection_rate  max_recovery_rate
# Country/Region
# Afghanistan                  915.0             1930.0
# Albania                      158.0              110.0
# Algeria                      675.0              749.0
# Andorra                       79.0               57.0
# Angola                       100.0               94.0

# %%
x=data["max_infection_rate"]
y=data["max_recovery_rate"]
sns.scatterplot(x,y)

# %%
sns.regplot(x,y)
